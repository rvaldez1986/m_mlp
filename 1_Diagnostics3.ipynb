# %%
import os
import pandas as pd
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Work with Diagnostics

# %%
os.chdir('C:\\Users\\rober\\Desktop\\Humana_2\\Data_1')
data = pd.read_csv("BASE_TRAIN_MODELOS.csv", sep=',', encoding = 'ISO-8859-1')
data['AFILIADO'] = data['AFILIADO'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
data = data.drop_duplicates(subset=['AFILIADO', 'PERIODO'], keep='first', inplace=False).reset_index(drop=True)

# %%
data_touse = data[['AFILIADO', 'PERIODO', 'DIAGNOSTICO_A', 'PAGADO_A.1']].copy()
data_touse.head(10)
# Out:
#                            AFILIADO    PERIODO  \
# 0           ABAD AREVALO CARLA MARA  2014-2015
# 1     ABAD CABANILLA CARMEN BEATRIZ  2014-2015
# 2       ABAD ROMERO CECILIA EUGENIA  2014-2015
# 3  ABARCA AGUIRRE MARIELA MARGARITA  2014-2015
# 4   ABARCA TORRES CARLOS VICTORIANO  2014-2015
# 5       ABRIL MONTEROS DENNIS DIEGO  2014-2015
# 6              ACERO GONZALEZ JORGE  2014-2015
# 7  ACEVEDO RIPALDA ALLISON PATRICIA  2014-2015
# 8  ACHI GONZALEZ JACQUELINE PRICILA  2014-2015
# 9       ACOSTA BALSECA EDGAR RAMIRO  2014-2015
#
#                                        DIAGNOSTICO_A  PAGADO_A.1
# 0                                               H605       15.00
# 1  M130, A09X, J304, J310, K30X, N709, M214, N925...      152.75
# 2  J00X, M170, I10X, I450, M179, J40X, N739, N72X...      370.48
# 3                                   N850, N939, M350      210.55
# 4                                                 ND        0.00
# 5                                                 ND        0.00
# 6                                               B829        0.00
# 7                       E039, E282, D539, G439, E221      288.26
# 8                                                 ND       52.36
# 9                                   K760, J029, E789       40.15

# %% [markdown]
# It is important to check if afiliados-anio is unique:

# %%
(data_touse['AFILIADO'] + '_' + data_touse['PERIODO']).is_unique
# Out:
# True

# %% [markdown]
# ## Create data matrix (Y)
#
# For this first we create a dictionary of unique diagnostics, all with count zero. This is going to be our start data for each assured:

# %%
def update_set(mset, diag):
    mset.update([x.strip() for x in diag.split(',')])
    
mset = set()    

for ld in data_touse['DIAGNOSTICO_A']:
    update_set(mset, ld)   
    
mdict = dict.fromkeys(mset, 0)
mdict
# Out:
# {'H179': 0,
#  'R104': 0,
#  'N761': 0,
#  'K528': 0,
#  'K804': 0,
#  'D698': 0,
#  'I841': 0,
#  'K290': 0,
#  'I471': 0,
#  'L200': 0,
#  'M220': 0,
#  'I499': 0,
#  'T182': 0,
#  'S345': 0,
#  'N44X': 0,
#  'M898': 0,
#  'S335': 0,
#  'D508': 0,
#  'M233': 0,
#  'S022': 0,
#  'B581': 0,
#  'I872': 0,
#  'R896': 0,
#  'E889': 0,
#  'S136': 0,
#  'I847': 0,
#  'L928': 0,
#  'R008': 0,
#  'M089': 0,
#  'I831': 0,
#  'G575': 0,
#  'C600': 0,
#  'K099': 0,
#  'K717': 0,
#  'S927': 0,
#  'L941': 0,
#  'E220': 0,
#  'N63X': 0,
#  'K266': 0,
#  'R402': 0,
#  'D758': 0,
#  'J853': 0,
#  'M906': 0,
#  'PM10': 0,
#  'S833': 0,
#  'S526': 0,
#  'B814': 0,
#  'I059': 0,
#  'G811': 0,
#  'I862': 0,
#  'H830': 0,
#  'M242': 0,
#  'Q500': 0,
#  'K031': 0,
#  'Y496': 0,
#  'B005': 0,
#  'K710': 0,
#  'E127': 0,
#  'I709': 0,
#  'L708': 0,
#  'D649': 0,
#  'B338': 0,
#  'L26X': 0,
#  'G441': 0,
#  'M650': 0,
#  'M508': 0,
#  'M921': 0,
#  'G719': 0,
#  'R229': 0,
#  'A080': 0,
#  'N433': 0,
#  'C754': 0,
#  'L081': 0,
#  'N600': 0,
#  'C221': 0,
#  'L405': 0,
#  'Z431': 0,
#  'N912': 0,
#  'I509': 0,
#  'G530': 0,
#  'M503': 0,
#  'N498': 0,
#  'H599': 0,
#  'M332': 0,
#  'C058': 0,
#  'S341': 0,
#  'S012': 0,
#  'E804': 0,
#  'A46X': 0,
#  'D172': 0,
#  'D483': 0,
#  'L048': 0,
#  'K112': 0,
#  'S831': 0,
#  'B356': 0,
#  'D481': 0,
#  'J018': 0,
#  'O294': 0,
#  'M058': 0,
#  'R633': 0,
#  'R074': 0,
#  'S971': 0,
#  'D693': 0,
#  'K605': 0,
#  'B082': 0,
#  'S767': 0,
#  'I421': 0,
#  'H619': 0,
#  'J158': 0,
#  'S043': 0,
#  'I429': 0,
#  'H509': 0,
#  'D099': 0,
#  'Z014': 0,
#  'Z359': 0,
#  'M518': 0,
#  'L950': 0,
#  'F519': 0,
#  'L709': 0,
#  'G442': 0,
#  'N830': 0,
#  'J42X': 0,
#  'N892': 0,
#  'Z762': 0,
#  'B850': 0,
#  'L80X': 0,
#  'S463': 0,
#  'Y420': 0,
#  'K273': 0,
#  'K922': 0,
#  'L980': 0,
#  'H170': 0,
#  'E569': 0,
#  'N110': 0,
#  'M709': 0,
#  'S935': 0,
#  'Q560': 0,
#  'Q667': 0,
#  'N434': 0,
#  'L280': 0,
#  'N210': 0,
#  'B088': 0,
#  'Z136': 0,
#  'L281': 0,
#  'K623': 0,
#  'G450': 0,
#  'F509': 0,
#  'H932': 0,
#  'I251': 0,
#  'M674': 0,
#  'L564': 0,
#  'Q531': 0,
#  'K289': 0,
#  'K501': 0,
#  'M899': 0,
#  'A071': 0,
#  'K629': 0,
#  'H534': 0,
#  'N419': 0,
#  'D041': 0,
#  'N394': 0,
#  'Z340': 0,
#  'H530': 0,
#  'R620': 0,
#  'A058': 0,
#  'M750': 0,
#  'K621': 0,
#  'H659': 0,
#  'R610': 0,
#  'Z124': 0,
#  'S321': 0,
#  'H526': 0,
#  'C440': 0,
#  'N833': 0,
#  'Z309': 0,
#  'B000': 0,
#  'A57X': 0,
#  'H021': 0,
#  'Z392': 0,
#  'J328': 0,
#  'M359': 0,
#  'L119': 0,
#  'D162': 0,
#  'C460': 0,
#  'H186': 0,
#  'J371': 0,
#  'N942': 0,
#  'S359': 0,
#  'I729': 0,
#  'Z931': 0,
#  'N201': 0,
#  'M235': 0,
#  'J678': 0,
#  'B432': 0,
#  'R740': 0,
#  'B351': 0,
#  'M255': 0,
#  'J343': 0,
#  'L231': 0,
#  'N289': 0,
#  'R463': 0,
#  'T237': 0,
#  'T789': 0,
#  'L303': 0,
#  'S008': 0,
#  'T150': 0,
#  'S869': 0,
#  'H578': 0,
#  'M993': 0,
#  'A600': 0,
#  'Y029': 0,
#  'M859': 0,
#  'J91X': 0,
#  'R32X': 0,
#  'M303': 0,
#  'M608': 0,
#  'E018': 0,
#  'S917': 0,
#  'Z305': 0,
#  'A858': 0,
#  'R298': 0,
#  'H681': 0,
#  'K635': 0,
#  'M148': 0,
#  'H545': 0,
#  'I390': 0,
#  'L279': 0,
#  'K741': 0,
#  'K824': 0,
#  'J218': 0,
#  'N132': 0,
#  'N640': 0,
#  'Q059': 0,
#  'S609': 0,
#  'E898': 0,
#  'H518': 0,
#  'S092': 0,
#  'S029': 0,
#  'H319': 0,
#  'R470': 0,
#  'I029': 0,
#  'J980': 0,
#  'G729': 0,
#  'R590': 0,
#  'M939': 0,
#  'Q539': 0,
#  'H334': 0,
#  'D696': 0,
#  'S867': 0,
#  'M230': 0,
#  'E854': 0,
#  'I789': 0,
#  'F419': 0,
#  'O030': 0,
#  'D126': 0,
#  'L858': 0,
#  'T231': 0,
#  'R560': 0,
#  'N499': 0,
#  'M546': 0,
#  'T302': 0,
#  'M926': 0,
#  'S063': 0,
#  'N808': 0,
#  'M796': 0,
#  'F780': 0,
#  'B99X': 0,
#  'M894': 0,
#  'M060': 0,
#  'H903': 0,
#  'D689': 0,
#  'L272': 0,
#  'I843': 0,
#  'R12X': 0,
#  'PJ30': 0,
#  'M064': 0,
#  'R238': 0,
#  'K830': 0,
#  'I832': 0,
#  'L983': 0,
#  'R068': 0,
#  'M759': 0,
#  'L570': 0,
#  'I158': 0,
#  'E341': 0,
#  'H939': 0,
#  'M764': 0,
#  'M018': 0,
#  'L638': 0,
#  'M234': 0,
#  'L728': 0,
#  'B529': 0,
#  'N211': 0,
#  'A062': 0,
#  'M170': 0,
#  'S750': 0,
#  'G549': 0,
#  'K429': 0,
#  'D048': 0,
#  'C501': 0,
#  'I519': 0,
#  'M190': 0,
#  'B353': 0,
#  'H699': 0,
#  'L749': 0,
#  'N748': 0,
#  'K752': 0,
#  'L662': 0,
#  'S827': 0,
#  'M098': 0,
#  'K137': 0,
#  'Y574': 0,
#  'H400': 0,
#  'S234': 0,
#  'L040': 0,
#  'E213': 0,
#  'K296': 0,
#  'E119': 0,
#  'O209': 0,
#  'B348': 0,
#  'D043': 0,
#  'M480': 0,
#  'G309': 0,
#  'A809': 0,
#  'D180': 0,
#  'G10X': 0,
#  'B341': 0,
#  'T320': 0,
#  'O289': 0,
#  'H527': 0,
#  'L028': 0,
#  'M840': 0,
#  'E709': 0,
#  'N318': 0,
#  'C770': 0,
#  'I958': 0,
#  'Z000': 0,
#  'W540': 0,
#  'C61X': 0,
#  'M772': 0,
#  'Z099': 0,
#  'L540': 0,
#  'S925': 0,
#  'I842': 0,
#  'H608': 0,
#  'Q618': 0,
#  'I48X': 0,
#  'D110': 0,
#  'J14X': 0,
#  'D640': 0,
#  'L248': 0,
#  'M765': 0,
#  'O13X': 0,
#  'F050': 0,
#  'S830': 0,
#  'D109': 0,
#  'M460': 0,
#  'I781': 0,
#  'L903': 0,
#  'G570': 0,
#  'I349': 0,
#  'D822': 0,
#  'G470': 0,
#  'R102': 0,
#  'A689': 0,
#  'H819': 0,
#  'R635': 0,
#  'O998': 0,
#  'Z889': 0,
#  'S730': 0,
#  'N879': 0,
#  'R293': 0,
#  'R11X': 0,
#  'D214': 0,
#  'E048': 0,
#  'S899': 0,
#  'G473': 0,
#  'L519': 0,
#  'K314': 0,
#  'S763': 0,
#  'M654': 0,
#  'D070': 0,
#  'C504': 0,
#  'E781': 0,
#  'B402': 0,
#  'B069': 0,
#  'S031': 0,
#  'W549': 0,
#  'S508': 0,
#  'J351': 0,
#  'Q627': 0,
#  'N889': 0,
#  'H604': 0,
#  'R101': 0,
#  'N941': 0,
#  'H062': 0,
#  'R160': 0,
#  'K604': 0,
#  'E749': 0,
#  'T230': 0,
#  'N369': 0,
#  'T261': 0,
#  'Q078': 0,
#  'L251': 0,
#  'L238': 0,
#  'A069': 0,
#  'M439': 0,
#  'N915': 0,
#  'S003': 0,
#  'Z308': 0,
#  'L819': 0,
#  'Q549': 0,
#  'G587': 0,
#  'M612': 0,
#  'S497': 0,
#  'R031': 0,
#  'H664': 0,
#  'Z320': 0,
#  'K573': 0,
#  'S408': 0,
#  'S208': 0,
#  'N999': 0,
#  'M180': 0,
#  'M901': 0,
#  'H690': 0,
#  'L919': 0,
#  'R196': 0,
#  'Y425': 0,
#  'M109': 0,
#  'K007': 0,
#  'J36X': 0,
#  'N009': 0,
#  'H709': 0,
#  'S920': 0,
#  'I849': 0,
#  'J011': 0,
#  'S600': 0,
#  'B181': 0,
#  'J040': 0,
#  'C449': 0,
#  'S599': 0,
#  'N870': 0,
#  'K293': 0,
#  'M919': 0,
#  'H748': 0,
#  'A199': 0,
#  'S400': 0,
#  'Z018': 0,
#  'Q601': 0,
#  'N925': 0,
#  'M069': 0,
#  'S320': 0,
#  'S059': 0,
#  'F009': 0,
#  'A509': 0,
#  'M755': 0,
#  'L658': 0,
#  'H100': 0,
#  'PH40': 0,
#  'K279': 0,
#  'F169': 0,
#  'S521': 0,
#  'R522': 0,
#  'K402': 0,
#  'I498': 0,
#  'M910': 0,
#  'B349': 0,
#  'S969': 0,
#  'H621': 0,
#  'R103': 0,
#  'Q750': 0,
#  'D319': 0,
#  'J410': 0,
#  'D439': 0,
#  'N602': 0,
#  'PN40': 0,
#  'N450': 0,
#  'M510': 0,
#  'E209': 0,
#  'N220': 0,
#  'M154': 0,
#  'J849': 0,
#  'S933': 0,
#  'S667': 0,
#  'T131': 0,
#  'M431': 0,
#  'S522': 0,
#  'N644': 0,
#  'T887': 0,
#  'H911': 0,
#  'L020': 0,
#  'M210': 0,
#  'S984': 0,
#  'L230': 0,
#  'K759': 0,
#  'R222': 0,
#  'D752': 0,
#  'L813': 0,
#  'A491': 0,
#  'L030': 0,
#  'L234': 0,
#  'S799': 0,
#  'L210': 0,
#  'L664': 0,
#  'Q900': 0,
#  'H611': 0,
#  'S924': 0,
#  'H481': 0,
#  'L97X': 0,
#  'PH11': 0,
#  'K140': 0,
#  'H432': 0,
#  'R090': 0,
#  'R798': 0,
#  'D70X': 0,
#  'O200': 0,
#  'H401': 0,
#  'S462': 0,
#  'PM81': 0,
#  'K593': 0,
#  'D040': 0,
#  'K122': 0,
#  'N62X': 0,
#  'H192': 0,
#  'H46X': 0,
#  'E102': 0,
#  'S340': 0,
#  'L209': 0,
#  'Q249': 0,
#  'O267': 0,
#  'H438': 0,
#  'M059': 0,
#  'E215': 0,
#  'L904': 0,
#  'M818': 0,
#  'K238': 0,
#  'Z010': 0,
#  'D751': 0,
#  'S747': 0,
#  'L814': 0,
#  'D010': 0,
#  'L738': 0,
#  'G041': 0,
#  'D62X': 0,
#  'Y424': 0,
#  'I071': 0,
#  'N259': 0,
#  'F489': 0,
#  'G448': 0,
#  'S860': 0,
#  'Z300': 0,
#  'L409': 0,
#  'L910': 0,
#  'A028': 0,
#  'L578': 0,
#  'N959': 0,
#  'H910': 0,
#  'M721': 0,
#  'Q874': 0,
#  'S229': 0,
#  'G519': 0,
#  'S617': 0,
#  'E281': 0,
#  'T733': 0,
#  'F072': 0,
#  'M703': 0,
#  'M815': 0,
#  'Z391': 0,
#  'E878': 0,
#  'C099': 0,
#  'N96X': 0,
#  'I200': 0,
#  'S501': 0,
#  'M203': 0,
#  'D269': 0,
#  'K310': 0,
#  'K529': 0,
#  'M329': 0,
#  'Q610': 0,
#  'O100': 0,
#  'S828': 0,
#  'J205': 0,
#  'K079': 0,
#  'A920': 0,
#  'L532': 0,
#  'S499': 0,
#  'M848': 0,
#  'R270': 0,
#  'B150': 0,
#  'R220': 0,
#  'B199': 0,
#  'M469': 0,
#  'P289': 0,
#  'G431': 0,
#  'N643': 0,
#  'N645': 0,
#  'L305': 0,
#  'N801': 0,
#  'L852': 0,
#  'K040': 0,
#  'G736': 0,
#  'N179': 0,
#  'C23X': 0,
#  'S923': 0,
#  'G440': 0,
#  'M715': 0,
#  'R619': 0,
#  'S300': 0,
#  'J350': 0,
#  'E078': 0,
#  'N958': 0,
#  'I270': 0,
#  'K519': 0,
#  'Q387': 0,
#  'S498': 0,
#  'K828': 0,
#  'N308': 0,
#  'N911': 0,
#  'I130': 0,
#  'J381': 0,
#  'S421': 0,
#  'K076': 0,
#  'K599': 0,
#  'A878': 0,
#  'M942': 0,
#  'E441': 0,
#  'N72X': 0,
#  'G589': 0,
#  'C052': 0,
#  'I64X': 0,
#  'PL93': 0,
#  'H571': 0,
#  'K805': 0,
#  'Z450': 0,
#  'N760': 0,
#  'D648': 0,
#  'M856': 0,
#  'W579': 0,
#  'P109': 0,
#  'H532': 0,
#  'T143': 0,
#  'L649': 0,
#  'D316': 0,
#  'I351': 0,
#  'J989': 0,
#  'S409': 0,
#  'N951': 0,
#  'R33X': 0,
#  'C158': 0,
#  'H101': 0,
#  'I803': 0,
#  'N302': 0,
#  'J189': 0,
#  'M139': 0,
#  'D047': 0,
#  'O021': 0,
#  'R300': 0,
#  'H651': 0,
#  'S142': 0,
#  'D359': 0,
#  'N771': 0,
#  'K800': 0,
#  'N922': 0,
#  'E788': 0,
#  'H600': 0,
#  'B509': 0,
#  'S299': 0,
#  'K739': 0,
#  'L42X': 0,
#  'H543': 0,
#  'K750': 0,
#  'T179': 0,
#  'E309': 0,
#  'L080': 0,
#  'J311': 0,
#  'L290': 0,
#  'J028': 0,
#  'S909': 0,
#  'E892': 0,
#  'S399': 0,
#  'J303': 0,
#  'I342': 0,
#  'I749': 0,
#  'N914': 0,
#  'Y96X': 0,
#  'M816': 0,
#  'B89X': 0,
#  'R010': 0,
#  'H001': 0,
#  'S332': 0,
#  'R060': 0,
#  'B880': 0,
#  'Q752': 0,
#  'L131': 0,
#  'C548': 0,
#  'S822': 0,
#  'D252': 0,
#  'B303': 0,
#  'J359': 0,
#  'H650': 0,
#  'L812': 0,
#  'I110': 0,
#  'M461': 0,
#  'S851': 0,
#  'E45X': 0,
#  'M621': 0,
#  'R739': 0,
#  'D171': 0,
#  'S523': 0,
#  'T16X': 0,
#  'E060': 0,
#  'S436': 0,
#  'H103': 0,
#  'K758': 0,
#  'V968': 0,
#  'T181': 0,
#  'N764': 0,
#  'R15X': 0,
#  'G838': 0,
#  'E058': 0,
#  'H269': 0,
#  'N923': 0,
#  'N903': 0,
#  'E46X': 0,
#  'L439': 0,
#  'M169': 0,
#  'A000': 0,
#  'E780': 0,
#  'T849': 0,
#  'M509': 0,
#  'S060': 0,
#  'D538': 0,
#  'L599': 0,
#  'Z019': 0,
#  'C709': 0,
#  'N341': 0,
#  'T171': 0,
#  'M775': 0,
#  'M790': 0,
#  'T189': 0,
#  'M751': 0,
#  'PI34': 0,
#  'C508': 0,
#  'B86X': 0,
#  'E214': 0,
#  'J323': 0,
#  'S913': 0,
#  'I868': 0,
#  'S051': 0,
#  'C56X': 0,
#  'B081': 0,
#  'M471': 0,
#  'R701': 0,
#  'S697': 0,
#  'J320': 0,
#  'D760': 0,
#  'A419': 0,
#  'L208': 0,
#  'N899': 0,
#  'T783': 0,
#  'E784': 0,
#  'T220': 0,
#  'S47X': 0,
#  'M501': 0,
#  'D000': 0,
#  'Z488': 0,
#  'K612': 0,
#  'L859': 0,
#  'S004': 0,
#  'G443': 0,
#  'S631': 0,
#  'A661': 0,
#  'D164': 0,
#  'T840': 0,
#  'Z108': 0,
#  'K041': 0,
#  'E279': 0,
#  'N759': 0,
#  'E114': 0,
#  'L920': 0,
#  'A029': 0,
#  'E040': 0,
#  'T809': 0,
#  'I840': 0,
#  'G629': 0,
#  'J440': 0,
#  'R80X': 0,
#  'S420': 0,
#  'M328': 0,
#  'E162': 0,
#  'N891': 0,
#  'J633': 0,
#  'K592': 0,
#  'A159': 0,
#  'B369': 0,
#  'Q240': 0,
#  'E109': 0,
#  'C793': 0,
#  'I350': 0,
#  'T301': 0,
#  'B302': 0,
#  'K102': 0,
#  'N309': 0,
#  'J111': 0,
#  'B021': 0,
#  'K011': 0,
#  'L932': 0,
#  'R509': 0,
#  'E069': 0,
#  'S698': 0,
#  'Q716': 0,
#  'E859': 0,
#  'G609': 0,
#  'J312': 0,
#  'C008': 0,
#  'B839': 0,
#  'S832': 0,
#  'Q668': 0,
#  'F349': 0,
#  'E108': 0,
#  'N849': 0,
#  'N778': 0,
#  'T091': 0,
#  'H660': 0,
#  'G038': 0,
#  'T793': 0,
#  'I340': 0,
#  'Z916': 0,
#  'R749': 0,
#  'E031': 0,
#  'Q785': 0,
#  'K254': 0,
#  'D692': 0,
#  'O219': 0,
#  'L292': 0,
#  'PL20': 0,
#  'G479': 0,
#  'M779': 0,
#  'K625': 0,
#  'G619': 0,
#  'K740': 0,
#  'E131': 0,
#  'Q664': 0,
#  'K518': 0,
#  'I443': 0,
#  'K520': 0,
#  'J851': 0,
#  'W550': 0,
#  'T118': 0,
#  'C448': 0,
#  'I472': 0,
#  'K229': 0,
#  'D170': 0,
#  'I500': 0,
#  'A58X': 0,
#  'I501': 0,
#  'R480': 0,
#  'K589': 0,
#  'L52X': 0,
#  'E269': 0,
#  'D391': 0,
#  'S601': 0,
#  'D039': 0,
#  'S207': 0,
#  'S311': 0,
#  'N800': 0,
#  'H050': 0,
#  'N920': 0,
#  'G544': 0,
#  'K818': 0,
#  'PJ34': 0,
#  'P393': 0,
#  'M625': 0,
#  'K269': 0,
#  'D232': 0,
#  'I208': 0,
#  'L240': 0,
#  'B820': 0,
#  'E063': 0,
#  'N328': 0,
#  'R51X': 0,
#  'A070': 0,
#  'N311': 0,
#  'E010': 0,
#  'H839': 0,
#  'Z954': 0,
#  'M843': 0,
#  'N709': 0,
#  'N138': 0,
#  'E110': 0,
#  'M725': 0,
#  'Q503': 0,
#  'S071': 0,
#  'J321': 0,
#  'S568': 0,
#  'M339': 0,
#  'L741': 0,
#  'L00X': 0,
#  'G711': 0,
#  'N872': 0,
#  'V902': 0,
#  'Q619': 0,
#  'H262': 0,
#  'S801': 0,
#  'H105': 0,
#  'S200': 0,
#  'J392': 0,
#  'S682': 0,
#  'L539': 0,
#  'H150': 0,
#  'M319': 0,
#  'M053': 0,
#  'N909': 0,
#  'R491': 0,
#  'M068': 0,
#  'R35X': 0,
#  'F525': 0,
#  'S525': 0,
#  'S922': 0,
#  'I00X': 0,
#  'W570': 0,
#  'I256': 0,
#  'A90X': 0,
#  'G521': 0,
#  'M600': 0,
#  'O218': 0,
#  'M009': 0,
#  'S017': 0,
#  'K868': 0,
#  'K767': 0,
#  'S901': 0,
#  'K578': 0,
#  'L22X': 0,
#  'D150': 0,
#  'F339': 0,
#  'N158': 0,
#  'N840': 0,
#  'S534': 0,
#  'D849': 0,
#  'K277': 0,
#  'L84X': 0,
#  'T090': 0,
#  'N850': 0,
#  'S119': 0,
#  'I259': 0,
#  'G540': 0,
#  'F03X': 0,
#  'I359': 0,
#  'E559': 0,
#  'H605': 0,
#  'D539': 0,
#  'L501': 0,
#  'B580': 0,
#  'J330': 0,
#  'N648': 0,
#  'B589': 0,
#  'H132': 0,
#  'H335': 0,
#  'K010': 0,
#  'H104': 0,
#  'J038': 0,
#  'D169': 0,
#  'Q669': 0,
#  'J209': 0,
#  'N319': 0,
#  'L759': 0,
#  'M753': 0,
#  'C409': 0,
#  'PM45': 0,
#  'S908': 0,
#  'I129': 0,
#  'E660': 0,
#  'L410': 0,
#  'N378': 0,
#  'H162': 0,
#  'S808': 0,
#  'S835': 0,
#  'E729': 0,
#  'Q248': 0,
#  'K294': 0,
#  'L309': 0,
#  'ND': 0,
#  'I879': 0,
#  'N139': 0,
#  'L729': 0,
#  'N300': 0,
#  'E042': 0,
#  'L602': 0,
#  'J370': 0,
#  'K639': 0,
#  'B083': 0,
#  'O862': 0,
#  'H959': 0,
#  'H160': 0,
#  'E799': 0,
#  'S903': 0,
#  'E68X': 0,
#  'A061': 0,
#  'M253': 0,
#  'M138': 0,
#  ...}

# %% [markdown]
# Now we create a matrix and populate with 1ones for each assured that suffered a diagnosis:

# %%
Y = np.zeros((data_touse.shape[0], len(mset)))

for i in range(Y.shape[0]):

    diags = data_touse['DIAGNOSTICO_A'][i]
    ldiags = [x.strip() for x in diags.split(',')]
    
    for d in ldiags:
        mdict[d] = 1
   
    Y[i,:] = list(mdict.values())
    mdict = dict.fromkeys(mset, 0)

# %% [markdown]
# And we are done!
#
# ## Apply Matrix Filtering Algorithm:
#
# We use the formulas for the improved algorithm:

# %%
def costFunction(Y, U, V):
    #Compute cost for given Y (data), U, V
    Y_h = np.dot(U.T,V)    
    S1 = Y - Y_h
    J = np.trace(np.dot(S1.T,S1))
    return J/(Y.shape[0]*Y.shape[1])

def compS(Y, U, V):
    Y_h = np.dot(U.T,V)
    S1 = Y - Y_h 
    return S1

def UGrad(S, U, V, ctnt):
    N = U.shape[1]  
    K = U.shape[0]
    U_grad = np.zeros((K,N))
    for i in range(N):
        U_grad[:,i] = -(2/ctnt) * (S[i,:] * V).sum(axis=1)
    return U_grad

def VGrad(S, U, V, ctnt):
    M = V.shape[1]  
    K = U.shape[0]
    V_grad = np.zeros((K,M))
    for j in range(M):
        V_grad[:,j] = -(2/ctnt) * (S[:,j] * U).sum(axis=1)
    return V_grad

def Update(U, U_grad, alpha):
    U = U - alpha*U_grad
    return U    

def Vpdate(V, V_grad, alpha):
    V = V - alpha*V_grad
    return V

# %%
#U = np.random.randn(K,N)   #We give random starting values for user parameters
#V = np.random.randn(K,M)   #We give random starting values for product parameters
U = np.load('U.npy')
V = np.load('V.npy')

# %%
N = Y.shape[0]  #Number of users
M = Y.shape[1]  #Number of products
K = 3  #Latent Features

# %%
J = []  #Create an empty vector J
epochs = 4000  #Number of loops around our data
alpha = 0.0001
#ctnt = M * N
ctnt = 1
print_every = 20

# %%
for l in range(epochs):    
    
    S = compS(Y,U,V)
    
    U_grad = UGrad(S, U, V, ctnt)
    
    V_grad = VGrad(S, U, V, ctnt)      
    
    U = Update(U, U_grad, alpha)
    V = Vpdate(V, V_grad, alpha)
    
    e = costFunction(Y, U, V)
    J.append(e)
    
    if l+1 >= print_every and (l+1) % print_every == 0:
        print("Loop around data number {0} of {1}, error = {2}".format(l+1, epochs, e))
# Out:
# Loop around data number 20 of 4000, error = 0.0013163938332776163
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-d227ba604aad> in <module>
#      10     V = Vpdate(V, V_grad, alpha)
#      11
# ---> 12     e = costFunction(Y, U, V)
#      13     J.append(e)
#      14
#
# <ipython-input-7-e6e2496da78f> in costFunction(Y, U, V)
#       3     Y_h = np.dot(U.T,V)
#       4     S1 = Y - Y_h
# ----> 5     J = np.trace(np.dot(S1.T,S1))
#       6     return J/(Y.shape[0]*Y.shape[1])
#       7
#
# KeyboardInterrupt:

# %% [markdown]
# Now lets save them for later use in training:

# %%
np.save('U.npy', U)
np.save('V.npy', V)

# %% [markdown]
# ## Save Results
#
# And lets prepare them for modelling. First the persons features database:

# %%
df = pd.DataFrame(U.T)
df.columns = ['diag_f1','diag_f2','diag_f3']

# %%
data_touse = pd.concat([data_touse, df], axis=1)
data_touse.head(3)
# Out:
#                         AFILIADO    PERIODO  \
# 0        ABAD AREVALO CARLA MARA  2014-2015
# 1  ABAD CABANILLA CARMEN BEATRIZ  2014-2015
# 2    ABAD ROMERO CECILIA EUGENIA  2014-2015
#
#                                        DIAGNOSTICO_A  PAGADO_A.1   diag_f1  \
# 0                                               H605       15.00 -0.526898
# 1  M130, A09X, J304, J310, K30X, N709, M214, N925...      152.75  0.228049
# 2  J00X, M170, I10X, I450, M179, J40X, N739, N72X...      370.48 -0.857004
#
#     diag_f2   diag_f3
# 0  0.155419  0.012823
# 1  0.291613 -0.170468
# 2  0.744933 -0.600182

# %%
data_touse.to_csv("nuevas\\pers_diag.csv", encoding='utf-8', index=False)
del [df]

# %% [markdown]
# Now the diagnostic features:

# %%
df = pd.concat([pd.DataFrame(mdict.keys()), pd.DataFrame(V.T)], axis=1)
df.columns = ['diag', 'diag2_f1','diag2_f2','diag2_f3']
df.to_csv("nuevas\\cdiag_diag.csv", encoding='utf-8', index=False)
