# %%
import os
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
import torch.nn as nn
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
np.random.seed(0)
data = pd.read_csv("Data\\cle\\Rand_train.csv", sep=',')
data = shuffle(data).reset_index(drop=True)
data_val = pd.read_csv("Data\\cle\\Rand_valid.csv", sep=',')

# %%
X = data.iloc[:,1:]
Y = data.iloc[:,0]
X_val = data_val.iloc[:,1:]
Y_val = data_val.iloc[:,0]

X2 = X
X2_val = X_val

# %%
cut = 0
y1 = (Y <= cut) * 1
y2 = (Y > cut) * (-1) * (-Y)
Y2 = np.stack((y1, y2), axis=-1)

y1_val = (Y_val <= cut) * 1
y2_val = (Y_val > cut) * (-1) * (-Y_val)
Y2_val = np.stack((y1_val, y2_val), axis=-1)

# %%
from fit91_nn import fit, comb_error, mae_error

# %%
class Net1(nn.Module):
    def __init__(self):
        super(Net1, self).__init__()
        
        self.fc11 = nn.Linear(16, 24, bias=True)
        self.fc12 = nn.Linear(24, 1, bias=True)
        
        self.fc21 = nn.Linear(16, 24)
        self.fc22 = nn.Linear(24, 5)
        self.fc23 = nn.Linear(5, 1)
        
        self.fc31 = nn.Linear(2,2, bias=False)
        
    def disc_activation(self, h):
        v1 = torch.sigmoid(h[:,0])
        v2 = torch.exp(h[:,1])
        return torch.stack((v1, v2), dim=1)
                
    def forward(self, x):
        x1 = torch.tanh(self.fc11(x))
        x1 = self.fc12(x1)
        
        x2 = self.fc21(x)
        x2 = F.relu(self.fc22(x2))
        x2 = self.fc23(x2)              
        
        x3 = torch.cat((x1, x2), 1)
        x3 = self.fc31(x3)
        x3 = self.disc_activation(x3)
        return x3

# %%
n_epochs = 200
lr = 0.0001
verbose = 1
n_batches = 6
batch_to_avg = 2
ep_to_check = 5
clipping = 0.20
sig2 = 2 * 950000
PATH = 'Data\\checkpoints\\mytraining4.pt'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def m_error(output, target):
    return comb_error(output, target, sig2)

# %%
def weights_init_normal(m):     
    classname = m.__class__.__name__
    torch.manual_seed(0)
    if classname.find('Linear') != -1:
        n = m.in_features
        y = 1.0/np.sqrt(n)
        m.weight.data.normal_(0, y)
        if m.bias is not None:
            m.bias.data.normal_(0, y)

# %%
def weights_init_uniform_rule(m):
    classname = m.__class__.__name__
    torch.manual_seed(0)
    if classname.find('Linear') != -1:
        n = m.in_features
        y = 1.0/np.sqrt(n)
        m.weight.data.uniform_(-y, y)
        m.bias.data.data.uniform_(-y, y)

# %%
net = Net1()
#optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.9)  
optimizer = optim.Adam(net.parameters(), lr=lr)

net.apply(weights_init_normal)
#net.apply(weights_init_uniform_rule)

#PATH = 'C:\\Users\\rober\\Desktop\\RAND_pro\\Data\\checkpoints\\mytraining4.pt'
#net.load_state_dict(torch.load(PATH, map_location = device))
    
a, b, c = fit(X=X2, X_val=X2_val, Y=Y2, Y_val=Y2_val, net=net, optimizer=optimizer, error=m_error, val_error = mae_error,
                n_epochs=n_epochs, n_batches=n_batches, batch_to_avg=batch_to_avg, 
                    ep_to_check=ep_to_check, clipping=clipping, PATH=PATH, device=device, 
                                            verbose=verbose, min_val_loss = float('inf'))

#(PENDIENTE)
# Out:
# Epoch 1: Training Loss: 1.0699357390403748, Validation Loss: 289.31280517578125
# Epoch 2: Training Loss: 1.0617754757404327, Validation Loss: 289.25811767578125
# Epoch 3: Training Loss: 1.0538318355878193, Validation Loss: 289.1998291015625
# Epoch 4: Training Loss: 1.0461992522080739, Validation Loss: 289.1378479003906
# Epoch 5: Training Loss: 1.038874218861262, Validation Loss: 289.0718078613281
# Epoch 6: Training Loss: 1.0317421456178029, Validation Loss: 289.0020446777344
# New Checkpoint Saved into PATH
# Epoch 7: Training Loss: 1.0249967972437541, Validation Loss: 288.928466796875
# Epoch 8: Training Loss: 1.018320729335149, Validation Loss: 288.850830078125
# Epoch 9: Training Loss: 1.0120311081409454, Validation Loss: 288.76824951171875
# Epoch 10: Training Loss: 1.005840132633845, Validation Loss: 288.6802673339844
# Epoch 11: Training Loss: 0.9999780257542928, Validation Loss: 288.5867919921875
# New Checkpoint Saved into PATH
# Epoch 12: Training Loss: 0.9943526983261108, Validation Loss: 288.4879150390625
# Epoch 13: Training Loss: 0.9890811145305634, Validation Loss: 288.3832092285156
# Epoch 14: Training Loss: 0.9837536613146464, Validation Loss: 288.271728515625
# Epoch 15: Training Loss: 0.9789069294929504, Validation Loss: 288.15362548828125
# Epoch 16: Training Loss: 0.9740986029307047, Validation Loss: 288.0293884277344
# New Checkpoint Saved into PATH
# Epoch 17: Training Loss: 0.9696313242117564, Validation Loss: 287.8985595703125
# Epoch 18: Training Loss: 0.9653169016043345, Validation Loss: 287.76141357421875
# Epoch 19: Training Loss: 0.9611829121907552, Validation Loss: 287.61712646484375
# Epoch 20: Training Loss: 0.9572805861632029, Validation Loss: 287.4680480957031
# Epoch 21: Training Loss: 0.9535615543524424, Validation Loss: 287.3136291503906
# New Checkpoint Saved into PATH
# Epoch 22: Training Loss: 0.9499656359354655, Validation Loss: 287.15350341796875
# Epoch 23: Training Loss: 0.9466034770011902, Validation Loss: 286.98736572265625
# Epoch 24: Training Loss: 0.9434357384840647, Validation Loss: 286.816162109375
# Epoch 25: Training Loss: 0.9404092530409495, Validation Loss: 286.641845703125
# Epoch 26: Training Loss: 0.9375907878081003, Validation Loss: 286.4656677246094
# New Checkpoint Saved into PATH
# Epoch 27: Training Loss: 0.9348638852437338, Validation Loss: 286.2873229980469
# Epoch 28: Training Loss: 0.9323257207870483, Validation Loss: 286.10662841796875
# Epoch 29: Training Loss: 0.9298772513866425, Validation Loss: 285.92791748046875
# Epoch 30: Training Loss: 0.9276848534742991, Validation Loss: 285.7496337890625
# Epoch 31: Training Loss: 0.9255602558453878, Validation Loss: 285.5727844238281
# New Checkpoint Saved into PATH
# Epoch 32: Training Loss: 0.9236120382944742, Validation Loss: 285.39501953125
# Epoch 33: Training Loss: 0.9217075606187185, Validation Loss: 285.2233581542969
# Epoch 34: Training Loss: 0.9199074804782867, Validation Loss: 285.059814453125
# Epoch 35: Training Loss: 0.918293962876002, Validation Loss: 284.89959716796875
# Epoch 36: Training Loss: 0.9168302516142527, Validation Loss: 284.7398681640625
# New Checkpoint Saved into PATH
# Epoch 37: Training Loss: 0.9153502881526947, Validation Loss: 284.5901794433594
# Epoch 38: Training Loss: 0.9139869709809622, Validation Loss: 284.4424133300781
# Epoch 39: Training Loss: 0.9127137760321299, Validation Loss: 284.2967529296875
# Epoch 40: Training Loss: 0.9114448030789694, Validation Loss: 284.1609191894531
# Epoch 41: Training Loss: 0.9102723697821299, Validation Loss: 284.0332336425781
# New Checkpoint Saved into PATH
# Epoch 42: Training Loss: 0.9091288149356842, Validation Loss: 283.91253662109375
# Epoch 43: Training Loss: 0.9080765644709269, Validation Loss: 283.7949523925781
# Epoch 44: Training Loss: 0.9070382416248322, Validation Loss: 283.6866149902344
# Epoch 45: Training Loss: 0.9059928059577942, Validation Loss: 283.5845642089844
# Epoch 46: Training Loss: 0.9050028026103973, Validation Loss: 283.48779296875
# New Checkpoint Saved into PATH
# Epoch 47: Training Loss: 0.90401491522789, Validation Loss: 283.3896484375
# Epoch 48: Training Loss: 0.9030863245328268, Validation Loss: 283.30340576171875
# Epoch 49: Training Loss: 0.902158389488856, Validation Loss: 283.2181396484375
# Epoch 50: Training Loss: 0.9012527863184611, Validation Loss: 283.14013671875
# Epoch 51: Training Loss: 0.9003285864988962, Validation Loss: 283.0647277832031
# New Checkpoint Saved into PATH
# Epoch 52: Training Loss: 0.8994488418102264, Validation Loss: 282.9906005859375
# Epoch 53: Training Loss: 0.8985839088757833, Validation Loss: 282.9176025390625
# Epoch 54: Training Loss: 0.8977186381816864, Validation Loss: 282.8470458984375
# Epoch 55: Training Loss: 0.8968643943468729, Validation Loss: 282.7725524902344
# Epoch 56: Training Loss: 0.8960394064585367, Validation Loss: 282.7042541503906
# New Checkpoint Saved into PATH
# Epoch 57: Training Loss: 0.89522718389829, Validation Loss: 282.6333923339844
# Epoch 58: Training Loss: 0.8943872451782227, Validation Loss: 282.5622863769531
# Epoch 59: Training Loss: 0.8935898542404175, Validation Loss: 282.4871520996094
# Epoch 60: Training Loss: 0.8928291002909342, Validation Loss: 282.4200744628906
# Epoch 61: Training Loss: 0.892022043466568, Validation Loss: 282.3418273925781
# New Checkpoint Saved into PATH
# Epoch 62: Training Loss: 0.8912409941355387, Validation Loss: 282.2652587890625
# Epoch 63: Training Loss: 0.8904467423756918, Validation Loss: 282.17694091796875
# Epoch 64: Training Loss: 0.8897053798039755, Validation Loss: 282.0975036621094
# Epoch 65: Training Loss: 0.8889667193094889, Validation Loss: 282.018310546875
# Epoch 66: Training Loss: 0.888204038143158, Validation Loss: 281.93414306640625
# New Checkpoint Saved into PATH
# Epoch 67: Training Loss: 0.8874642252922058, Validation Loss: 281.8511657714844
# Epoch 68: Training Loss: 0.8867221971352895, Validation Loss: 281.771240234375
# Epoch 69: Training Loss: 0.8859929144382477, Validation Loss: 281.6842956542969
# Epoch 70: Training Loss: 0.8852527240912119, Validation Loss: 281.6011047363281
# Epoch 71: Training Loss: 0.884547233581543, Validation Loss: 281.5147399902344
# New Checkpoint Saved into PATH
# Epoch 72: Training Loss: 0.8838209013144175, Validation Loss: 281.4202575683594
# Epoch 73: Training Loss: 0.883092482884725, Validation Loss: 281.3205871582031
# Epoch 74: Training Loss: 0.8823944330215454, Validation Loss: 281.21917724609375
# Epoch 75: Training Loss: 0.8816567162672678, Validation Loss: 281.11004638671875
# Epoch 76: Training Loss: 0.8809687793254852, Validation Loss: 281.0100402832031
# New Checkpoint Saved into PATH
# Epoch 77: Training Loss: 0.8802729249000549, Validation Loss: 280.8974609375
# Epoch 78: Training Loss: 0.8795570234457651, Validation Loss: 280.7975158691406
# Epoch 79: Training Loss: 0.8788663844267527, Validation Loss: 280.6820983886719
# Epoch 80: Training Loss: 0.8781717618306478, Validation Loss: 280.5578918457031
# Epoch 81: Training Loss: 0.8774932324886322, Validation Loss: 280.4389343261719
# New Checkpoint Saved into PATH
# Epoch 82: Training Loss: 0.8768309156099955, Validation Loss: 280.31207275390625
# Epoch 83: Training Loss: 0.8761499524116516, Validation Loss: 280.1956787109375
# Epoch 84: Training Loss: 0.8754538595676422, Validation Loss: 280.0606384277344
# Epoch 85: Training Loss: 0.8747990826765696, Validation Loss: 279.92950439453125
# Epoch 86: Training Loss: 0.8741551538308462, Validation Loss: 279.7986145019531
# New Checkpoint Saved into PATH
# Epoch 87: Training Loss: 0.8734776973724365, Validation Loss: 279.6644592285156
# Epoch 88: Training Loss: 0.8728121121724447, Validation Loss: 279.50592041015625
# Epoch 89: Training Loss: 0.8721850117047628, Validation Loss: 279.3626708984375
# Epoch 90: Training Loss: 0.8715512951215109, Validation Loss: 279.2033386230469
# Epoch 91: Training Loss: 0.870868037144343, Validation Loss: 279.0503234863281
# New Checkpoint Saved into PATH
# Epoch 92: Training Loss: 0.8702332774798075, Validation Loss: 278.9109802246094
# Epoch 93: Training Loss: 0.8695783813794454, Validation Loss: 278.77825927734375
# Epoch 94: Training Loss: 0.8689283827940623, Validation Loss: 278.6242370605469
# Epoch 95: Training Loss: 0.8682937721411387, Validation Loss: 278.4707946777344
# Epoch 96: Training Loss: 0.8676543235778809, Validation Loss: 278.3138732910156
# New Checkpoint Saved into PATH
# Epoch 97: Training Loss: 0.8670242726802826, Validation Loss: 278.1421203613281
# Epoch 98: Training Loss: 0.8663761913776398, Validation Loss: 277.9924011230469
# Epoch 99: Training Loss: 0.8657748798529307, Validation Loss: 277.84100341796875
# Epoch 100: Training Loss: 0.865137537320455, Validation Loss: 277.67230224609375
# Epoch 101: Training Loss: 0.8645297884941101, Validation Loss: 277.4879150390625
# New Checkpoint Saved into PATH
# Epoch 102: Training Loss: 0.8639170626799265, Validation Loss: 277.29937744140625
# Epoch 103: Training Loss: 0.8632714549700419, Validation Loss: 277.1017150878906
# Epoch 104: Training Loss: 0.8626891175905863, Validation Loss: 276.90716552734375
# Epoch 105: Training Loss: 0.8620922664801279, Validation Loss: 276.69964599609375
# Epoch 106: Training Loss: 0.8615025679270426, Validation Loss: 276.4966125488281
# New Checkpoint Saved into PATH
# Epoch 107: Training Loss: 0.8609065512816111, Validation Loss: 276.2862854003906
# Epoch 108: Training Loss: 0.8603091637293497, Validation Loss: 276.0931091308594
# Epoch 109: Training Loss: 0.8597289125124613, Validation Loss: 275.89422607421875
# Epoch 110: Training Loss: 0.859146406253179, Validation Loss: 275.6764221191406
# Epoch 111: Training Loss: 0.8585466742515564, Validation Loss: 275.41778564453125
# New Checkpoint Saved into PATH
# Epoch 112: Training Loss: 0.8579739928245544, Validation Loss: 275.1749572753906
# Epoch 113: Training Loss: 0.8573885460694631, Validation Loss: 274.9419860839844
# Epoch 114: Training Loss: 0.8568248450756073, Validation Loss: 274.693603515625
# Epoch 115: Training Loss: 0.856238603591919, Validation Loss: 274.4136657714844
# Epoch 116: Training Loss: 0.8556340237458547, Validation Loss: 274.1463623046875
# New Checkpoint Saved into PATH
# Epoch 117: Training Loss: 0.8550754189491272, Validation Loss: 273.8927307128906
# Epoch 118: Training Loss: 0.8545071184635162, Validation Loss: 273.60369873046875
# Epoch 119: Training Loss: 0.8539349933465322, Validation Loss: 273.3102722167969
# Epoch 120: Training Loss: 0.853353331486384, Validation Loss: 273.01092529296875
# Epoch 121: Training Loss: 0.852793276309967, Validation Loss: 272.6983642578125
# New Checkpoint Saved into PATH
# Epoch 122: Training Loss: 0.8522333403428396, Validation Loss: 272.3538818359375
# Epoch 123: Training Loss: 0.851656953493754, Validation Loss: 272.0218811035156
# Epoch 124: Training Loss: 0.8510771791140238, Validation Loss: 271.6805725097656
# Epoch 125: Training Loss: 0.8505047162373861, Validation Loss: 271.3428039550781
# Epoch 126: Training Loss: 0.8499313990275065, Validation Loss: 270.98583984375
# New Checkpoint Saved into PATH
# Epoch 127: Training Loss: 0.8493256568908691, Validation Loss: 270.632568359375
# Epoch 128: Training Loss: 0.8487551709016165, Validation Loss: 270.258544921875
# Epoch 129: Training Loss: 0.8481442034244537, Validation Loss: 269.89532470703125
# Epoch 130: Training Loss: 0.8475496570269266, Validation Loss: 269.5362854003906
# Epoch 131: Training Loss: 0.8469704886277517, Validation Loss: 269.15673828125
# New Checkpoint Saved into PATH
# Epoch 132: Training Loss: 0.8463690181573232, Validation Loss: 268.7885437011719
# Epoch 133: Training Loss: 0.8457572360833486, Validation Loss: 268.3762512207031
# Epoch 134: Training Loss: 0.8451542953650156, Validation Loss: 267.94073486328125
# Epoch 135: Training Loss: 0.844530830780665, Validation Loss: 267.5210266113281
# Epoch 136: Training Loss: 0.8439141114552816, Validation Loss: 267.0899658203125
# New Checkpoint Saved into PATH
# Epoch 137: Training Loss: 0.8432830075422922, Validation Loss: 266.6395568847656
# Epoch 138: Training Loss: 0.84258105357488, Validation Loss: 266.21319580078125
# Epoch 139: Training Loss: 0.8419268329938253, Validation Loss: 265.8172912597656
# Epoch 140: Training Loss: 0.8412530024846395, Validation Loss: 265.43499755859375
# Epoch 141: Training Loss: 0.84055029352506, Validation Loss: 265.0802307128906
# New Checkpoint Saved into PATH
# Epoch 142: Training Loss: 0.8398796220620474, Validation Loss: 264.71612548828125
# Epoch 143: Training Loss: 0.8391675253709158, Validation Loss: 264.3659362792969
# Epoch 144: Training Loss: 0.8384465475877126, Validation Loss: 264.0046691894531
# Epoch 145: Training Loss: 0.837683786948522, Validation Loss: 263.6434326171875
# Epoch 146: Training Loss: 0.8369073867797852, Validation Loss: 263.305419921875
# New Checkpoint Saved into PATH
# Epoch 147: Training Loss: 0.8360677460829417, Validation Loss: 263.0259094238281
# Epoch 148: Training Loss: 0.8353335658709208, Validation Loss: 262.7803039550781
# Epoch 149: Training Loss: 0.8344608545303345, Validation Loss: 262.6006774902344
# Epoch 150: Training Loss: 0.8336344957351685, Validation Loss: 262.4576416015625
# Epoch 151: Training Loss: 0.8327540556589762, Validation Loss: 262.344970703125
# New Checkpoint Saved into PATH
# Epoch 152: Training Loss: 0.8319428165753683, Validation Loss: 262.28265380859375
# Epoch 153: Training Loss: 0.8310919404029846, Validation Loss: 262.2876281738281
# Epoch 154: Training Loss: 0.8301384349664053, Validation Loss: 262.35968017578125
# Epoch 155: Training Loss: 0.8292994995911916, Validation Loss: 262.4772033691406
# Epoch 156: Training Loss: 0.828430692354838, Validation Loss: 262.67218017578125
# New Checkpoint Saved into PATH
# Epoch 157: Training Loss: 0.8275785644849142, Validation Loss: 262.9557800292969
# Epoch 158: Training Loss: 0.8266492386658987, Validation Loss: 263.2859191894531
# Epoch 159: Training Loss: 0.8257953425248464, Validation Loss: 263.746337890625
# Epoch 160: Training Loss: 0.8249062200387319, Validation Loss: 264.32177734375
# Epoch 161: Training Loss: 0.8240861097971598, Validation Loss: 265.0676574707031
# Epoch 162: Training Loss: 0.8231294254461924, Validation Loss: 265.8436279296875
# Epoch 163: Training Loss: 0.8223698735237122, Validation Loss: 266.69403076171875
# Epoch 164: Training Loss: 0.821546882390976, Validation Loss: 267.5800476074219
# Epoch 165: Training Loss: 0.8207421004772186, Validation Loss: 268.47882080078125
# Epoch 166: Training Loss: 0.8200086752573649, Validation Loss: 269.4147644042969
# Epoch 167: Training Loss: 0.8192132512728373, Validation Loss: 270.26458740234375
# Epoch 168: Training Loss: 0.8184798459211985, Validation Loss: 271.17205810546875
# Epoch 169: Training Loss: 0.8177735606829325, Validation Loss: 272.0713806152344
# Epoch 170: Training Loss: 0.8170694212118784, Validation Loss: 273.0355529785156
# Epoch 171: Training Loss: 0.8164269030094147, Validation Loss: 273.92095947265625
# Epoch 172: Training Loss: 0.8157836397488912, Validation Loss: 274.90606689453125
# Epoch 173: Training Loss: 0.8152191936969757, Validation Loss: 275.6607971191406
# Epoch 174: Training Loss: 0.8145735462506613, Validation Loss: 276.3819274902344
# Epoch 175: Training Loss: 0.8140266438325247, Validation Loss: 276.9789733886719
# Epoch 176: Training Loss: 0.813530037800471, Validation Loss: 277.4102783203125
# Epoch 177: Training Loss: 0.8130005101362864, Validation Loss: 277.69598388671875
# Epoch 178: Training Loss: 0.8125734627246857, Validation Loss: 278.0039978027344
# Epoch 179: Training Loss: 0.8120497663815817, Validation Loss: 278.1667785644531
# Epoch 180: Training Loss: 0.8115999599297842, Validation Loss: 278.2461242675781
# Epoch 181: Training Loss: 0.8112151920795441, Validation Loss: 278.39215087890625
# Epoch 182: Training Loss: 0.8107436100641886, Validation Loss: 278.7064514160156
# Epoch 183: Training Loss: 0.8103534579277039, Validation Loss: 278.7634582519531
# Epoch 184: Training Loss: 0.8099454343318939, Validation Loss: 278.6360778808594
# Epoch 185: Training Loss: 0.8095949192841848, Validation Loss: 278.58447265625
# Epoch 186: Training Loss: 0.8092773258686066, Validation Loss: 278.4460144042969
# Epoch 187: Training Loss: 0.8089572588602701, Validation Loss: 277.9411315917969
# Epoch 188: Training Loss: 0.8086457451184591, Validation Loss: 277.78009033203125
# Epoch 189: Training Loss: 0.8083585103352865, Validation Loss: 278.0813903808594
# Epoch 190: Training Loss: 0.8080184062321981, Validation Loss: 278.2164306640625
# Epoch 191: Training Loss: 0.8077330688635508, Validation Loss: 278.30535888671875
# Epoch 192: Training Loss: 0.8074848751227061, Validation Loss: 278.7207946777344
# Epoch 193: Training Loss: 0.807222937544187, Validation Loss: 278.6645202636719
# Epoch 194: Training Loss: 0.8069842358430227, Validation Loss: 278.4687194824219
# Epoch 195: Training Loss: 0.8067269921302795, Validation Loss: 278.2815246582031
# Epoch 196: Training Loss: 0.8064958651860555, Validation Loss: 278.01318359375
# Epoch 197: Training Loss: 0.8063163956006368, Validation Loss: 277.4535217285156
# Epoch 198: Training Loss: 0.8060788661241531, Validation Loss: 277.096435546875
# Epoch 199: Training Loss: 0.8059185743331909, Validation Loss: 276.9981994628906
# Epoch 200: Training Loss: 0.80571315685908, Validation Loss: 277.4212646484375
